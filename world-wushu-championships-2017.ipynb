# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
WWC17 = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/WWC17.csv")


WWC17
# Out:
#                   Name Country  Overall_Score  Rank  A_Score  B_Score  \
# 0        Zhizhao Chang     CHN           9.70     1      5.0     2.70
# 1       Achmad Hulaefi     INA           9.64     2      5.0     2.64
# 2        Pavel Muratov     RUS           9.63     3      5.0     2.63
# 3         Wai Kin Yeap     MAS           9.62     4      5.0     2.62
# 4         Hibiki Betto     JPN           9.58     5      5.0     2.58
# ..                 ...     ...            ...   ...      ...      ...
# 202        Leslie Kwan     CAN           8.56    23      4.6     2.41
# 203       Aditya Kumar     IND           8.54    24      4.6     2.39
# 204  Dan Rio Rodriguez     ESP           8.47    25      4.4     2.32
# 205       Yaowen Zhang     CHN           8.45    26      4.6     2.70
# 206         Reagan Tan     AUS           7.48    27      4.3     2.08
#
#      C_Score  Time PlaceCat   Region                    Event Gender  \
# ...

# %%
WWC17.head()
# Out:
#              Name Country  Overall_Score  Rank  A_Score  B_Score  C_Score  \
# 0   Zhizhao Chang     CHN           9.70     1      5.0     2.70      2.0
# 1  Achmad Hulaefi     INA           9.64     2      5.0     2.64      2.0
# 2   Pavel Muratov     RUS           9.63     3      5.0     2.63      2.0
# 3    Wai Kin Yeap     MAS           9.62     4      5.0     2.62      2.0
# 4    Hibiki Betto     JPN           9.58     5      5.0     2.58      2.0
#
#    Time PlaceCat  Region                 Event Gender B_Score_Cat  A_Ded_Cnt  \
# 0  1.40     Gold   China  Changquan (Longfist)      M    Superior          0
# 1  1.26    Top10    Asia  Changquan (Longfist)      M    Superior          0
# 2  1.25    Top10  Russia  Changquan (Longfist)      M    Superior          0
# 3  1.41    Top10    Asia  Changquan (Longfist)      M    Superior          0
# 4  1.27    Top10    Asia  Changquan (Longfist)      M    Superior          0
#
#    Nandu_Miss  Nandu_Total Nandu_Completed
# ...

# %%
WWC17.tail()
# Out:
#                   Name Country  Overall_Score  Rank  A_Score  B_Score  \
# 202        Leslie Kwan     CAN           8.56    23      4.6     2.41
# 203       Aditya Kumar     IND           8.54    24      4.6     2.39
# 204  Dan Rio Rodriguez     ESP           8.47    25      4.4     2.32
# 205       Yaowen Zhang     CHN           8.45    26      4.6     2.70
# 206         Reagan Tan     AUS           7.48    27      4.3     2.08
#
#      C_Score  Time PlaceCat   Region                    Event Gender  \
# 202     1.55  1.44    Top30  America  Jianshu (Straightsword)      M
# 203     1.55  1.26    Top30    India  Jianshu (Straightsword)      M
# 204     1.75  1.29    Top30   Europe  Jianshu (Straightsword)      M
# 205     1.15  1.45    Top30    China  Jianshu (Straightsword)      M
# 206     1.10  1.36    Top30  Oceanic  Jianshu (Straightsword)      M
#
#     B_Score_Cat  A_Ded_Cnt  Nandu_Miss  Nandu_Total Nandu_Completed
# ...

# %%
WWC17.describe()
# Out:
#        Overall_Score        Rank     A_Score     B_Score     C_Score  \
# count     207.000000  207.000000  207.000000  207.000000  207.000000
# mean        9.021353   18.801932    4.734300    2.467729    1.819324
# std         0.611582   11.740908    0.246593    0.160875    0.297830
# min         5.700000    1.000000    3.500000    1.700000    0.200000
# 25%         8.740000    9.000000    4.600000    2.370000    1.700000
# 50%         9.170000   18.000000    4.800000    2.490000    2.000000
# 75%         9.450000   27.000000    4.900000    2.600000    2.000000
# max         9.720000   50.000000    5.000000    2.720000    2.000000
#
#              Time   A_Ded_Cnt  Nandu_Miss  Nandu_Total
# count  207.000000  207.000000  207.000000   207.000000
# mean     1.334686    2.512077    0.975845    11.734300
# std      0.116539    2.250911    1.429372     1.000938
# min      1.210000    0.000000    0.000000     5.000000
# 25%      1.280000    1.000000    0.000000    12.000000
# ...

# %%
WWC17.info
# Out:
# <bound method DataFrame.info of                   Name Country  Overall_Score  Rank  A_Score  B_Score  \
# 0        Zhizhao Chang     CHN           9.70     1      5.0     2.70
# 1       Achmad Hulaefi     INA           9.64     2      5.0     2.64
# 2        Pavel Muratov     RUS           9.63     3      5.0     2.63
# 3         Wai Kin Yeap     MAS           9.62     4      5.0     2.62
# 4         Hibiki Betto     JPN           9.58     5      5.0     2.58
# ..                 ...     ...            ...   ...      ...      ...
# 202        Leslie Kwan     CAN           8.56    23      4.6     2.41
# 203       Aditya Kumar     IND           8.54    24      4.6     2.39
# 204  Dan Rio Rodriguez     ESP           8.47    25      4.4     2.32
# 205       Yaowen Zhang     CHN           8.45    26      4.6     2.70
# 206         Reagan Tan     AUS           7.48    27      4.3     2.08
#
#      C_Score  Time PlaceCat   Region                    Event Gender  \
# ...

# %%
WWC17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             207 non-null    object
#  1   Country          207 non-null    object
#  2   Overall_Score    207 non-null    float64
#  3   Rank             207 non-null    int64
#  4   A_Score          207 non-null    float64
#  5   B_Score          207 non-null    float64
#  6   C_Score          207 non-null    float64
#  7   Time             207 non-null    float64
#  8   PlaceCat         207 non-null    object
#  9   Region           207 non-null    object
#  10  Event            207 non-null    object
#  11  Gender           207 non-null    object
#  12  B_Score_Cat      207 non-null    object
#  13  A_Ded_Cnt        207 non-null    int64
#  14  Nandu_Miss       207 non-null    int64
#  15  Nandu_Total      207 non-null    int64
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("WWC17.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("WWC17.db")
c = conn.cursor()

# %%
WWC17.to_sql("WWC17", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM WWC17""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   'Zhizhao Chang',
#   'CHN',
#   9.7,
#   1,
#   5.0,
#   2.7,
#   2.0,
#   1.4,
#   'Gold',
#   'China',
#   'Changquan (Longfist)',
#   'M',
#   'Superior',
#   0,
#   0,
#   9,
#   '100%'),
#  (1,
#   'Achmad Hulaefi',
#   'INA',
#   9.64,
#   2,
#   5.0,
#   2.64,
#   2.0,
#   1.26,
#   'Top10',
#   'Asia',
#   'Changquan (Longfist)',
#   'M',
#   'Superior',
#   0,
#   0,
#   12,
#   '100%'),
#  (2,
#   'Pavel Muratov',
#   'RUS',
#   9.63,
#   3,
#   5.0,
#   2.63,
#   2.0,
#   1.25,
#   'Top10',
#   'Russia',
#   'Changquan (Longfist)',
#   'M',
#   'Superior',
#   0,
#   0,
#   11,
#   '100%'),
#  (3,
#   'Wai Kin Yeap',
#   'MAS',
#   9.62,
#   4,
#   5.0,
#   2.62,
#   2.0,
#   1.41,
#   'Top10',
#   'Asia',
#   'Changquan (Longfist)',
#   'M',
#   'Superior',
#   0,
#   0,
#   12,
#   '100%'),
#  (4,
#   'Hibiki Betto',
#   'JPN',
#   9.58,
#   5,
#   5.0,
#   2.58,
#   2.0,
#   1.27,
#   'Top10',
#   'Asia',
#   'Changquan (Longfist)',
#   'M',
#   'Superior',
# ...

# %%
WWC17.to_excel("WWC17.xls")

pd.read_excel("WWC17.xls")
# Out:
#      Unnamed: 0               Name Country  Overall_Score  Rank  A_Score  \
# 0             0      Zhizhao Chang     CHN           9.70     1      5.0
# 1             1     Achmad Hulaefi     INA           9.64     2      5.0
# 2             2      Pavel Muratov     RUS           9.63     3      5.0
# 3             3       Wai Kin Yeap     MAS           9.62     4      5.0
# 4             4       Hibiki Betto     JPN           9.58     5      5.0
# ..          ...                ...     ...            ...   ...      ...
# 202         202        Leslie Kwan     CAN           8.56    23      4.6
# 203         203       Aditya Kumar     IND           8.54    24      4.6
# 204         204  Dan Rio Rodriguez     ESP           8.47    25      4.4
# 205         205       Yaowen Zhang     CHN           8.45    26      4.6
# 206         206         Reagan Tan     AUS           7.48    27      4.3
#
#      B_Score  C_Score  Time PlaceCat   Region                    Event Gender  \
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('World Wushu Championships 2017', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('World Wushu Championships 2017')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Teams = pd.read_csv("https://raw.githubusercontent.com/christianwbsn/world-cup-2018-predictor/master/input/Teams.csv")

Teams
# Out:
#           Team  Points                                  Image
# 0      Germany    1544  //img.fifa.com/images/flags/4/ger.png
# 1       Brazil    1384  //img.fifa.com/images/flags/4/bra.png
# 2      Belgium    1346  //img.fifa.com/images/flags/4/bel.png
# 3     Portugal    1306  //img.fifa.com/images/flags/4/por.png
# 4    Argentina    1254  //img.fifa.com/images/flags/4/arg.png
# ..         ...     ...                                    ...
# 206   Anguilla       0  //img.fifa.com/images/flags/4/aia.png
# 207    Bahamas       0  //img.fifa.com/images/flags/4/bah.png
# 208    Eritrea       0  //img.fifa.com/images/flags/4/eri.png
# 209    Somalia       0  //img.fifa.com/images/flags/4/som.png
# 210      Tonga       0  //img.fifa.com/images/flags/4/tga.png
#
# [211 rows x 3 columns]

# %%
Teams.head()
# Out:
#         Team  Points                                  Image
# 0    Germany    1544  //img.fifa.com/images/flags/4/ger.png
# 1     Brazil    1384  //img.fifa.com/images/flags/4/bra.png
# 2    Belgium    1346  //img.fifa.com/images/flags/4/bel.png
# 3   Portugal    1306  //img.fifa.com/images/flags/4/por.png
# 4  Argentina    1254  //img.fifa.com/images/flags/4/arg.png

# %%
Teams.tail()
# Out:
#          Team  Points                                  Image
# 206  Anguilla       0  //img.fifa.com/images/flags/4/aia.png
# 207   Bahamas       0  //img.fifa.com/images/flags/4/bah.png
# 208   Eritrea       0  //img.fifa.com/images/flags/4/eri.png
# 209   Somalia       0  //img.fifa.com/images/flags/4/som.png
# 210     Tonga       0  //img.fifa.com/images/flags/4/tga.png

# %%
Teams.describe()
# Out:
#             Points
# count   211.000000
# mean    398.729858
# std     333.328964
# min       0.000000
# 25%     128.500000
# 50%     311.000000
# 75%     582.500000
# max    1544.000000

# %%
Teams.info
# Out:
# <bound method DataFrame.info of           Team  Points                                  Image
# 0      Germany    1544  //img.fifa.com/images/flags/4/ger.png
# 1       Brazil    1384  //img.fifa.com/images/flags/4/bra.png
# 2      Belgium    1346  //img.fifa.com/images/flags/4/bel.png
# 3     Portugal    1306  //img.fifa.com/images/flags/4/por.png
# 4    Argentina    1254  //img.fifa.com/images/flags/4/arg.png
# ..         ...     ...                                    ...
# 206   Anguilla       0  //img.fifa.com/images/flags/4/aia.png
# 207    Bahamas       0  //img.fifa.com/images/flags/4/bah.png
# 208    Eritrea       0  //img.fifa.com/images/flags/4/eri.png
# 209    Somalia       0  //img.fifa.com/images/flags/4/som.png
# 210      Tonga       0  //img.fifa.com/images/flags/4/tga.png
#
# [211 rows x 3 columns]>

# %%
Teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Team    211 non-null    object
#  1   Points  211 non-null    int64
#  2   Image   211 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 5.1+ KB

# %%
import sqlite3

# %%
conn = sqlite3.connect("Teams.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("Teams.db")
c = conn.cursor()

# %%
Teams.to_sql("Teams", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM Teams""")
rows = c.fetchall()
rows
# Out:
# [(0, 'Germany', 1544, '//img.fifa.com/images/flags/4/ger.png'),
#  (1, 'Brazil', 1384, '//img.fifa.com/images/flags/4/bra.png'),
#  (2, 'Belgium', 1346, '//img.fifa.com/images/flags/4/bel.png'),
#  (3, 'Portugal', 1306, '//img.fifa.com/images/flags/4/por.png'),
#  (4, 'Argentina', 1254, '//img.fifa.com/images/flags/4/arg.png'),
#  (5, 'Switzerland', 1179, '//img.fifa.com/images/flags/4/sui.png'),
#  (6, 'France', 1166, '//img.fifa.com/images/flags/4/fra.png'),
#  (7, 'Spain', 1162, '//img.fifa.com/images/flags/4/esp.png'),
#  (8, 'Chile', 1146, '//img.fifa.com/images/flags/4/chi.png'),
#  (9, 'Poland', 1128, '//img.fifa.com/images/flags/4/pol.png'),
#  (10, 'Peru', 1106, '//img.fifa.com/images/flags/4/per.png'),
#  (11, 'Denmark', 1054, '//img.fifa.com/images/flags/4/den.png'),
#  (12, 'England', 1040, '//img.fifa.com/images/flags/4/eng.png'),
#  (13, 'Tunisia', 1012, '//img.fifa.com/images/flags/4/uru.png'),
#  (14, 'Mexico', 1008, '//img.fifa.com/images/flags/4/mex.png'),
# ...

# %%
Teams.to_excel("Teams.xls")

pd.read_excel("Teams.xls")
# Out:
#      Unnamed: 0       Team  Points                                  Image
# 0             0    Germany    1544  //img.fifa.com/images/flags/4/ger.png
# 1             1     Brazil    1384  //img.fifa.com/images/flags/4/bra.png
# 2             2    Belgium    1346  //img.fifa.com/images/flags/4/bel.png
# 3             3   Portugal    1306  //img.fifa.com/images/flags/4/por.png
# 4             4  Argentina    1254  //img.fifa.com/images/flags/4/arg.png
# ..          ...        ...     ...                                    ...
# 206         206   Anguilla       0  //img.fifa.com/images/flags/4/aia.png
# 207         207    Bahamas       0  //img.fifa.com/images/flags/4/bah.png
# 208         208    Eritrea       0  //img.fifa.com/images/flags/4/eri.png
# 209         209    Somalia       0  //img.fifa.com/images/flags/4/som.png
# 210         210      Tonga       0  //img.fifa.com/images/flags/4/tga.png
#
# [211 rows x 4 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('world-cup-2018-predictor Teams.', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('world-cup-2018-predictor Teams.')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

# %%
pd.read_csv("https://raw.githubusercontent.com/christianwbsn/world-cup-2018-predictor/master/input/fifa_ranking.csv")
# Out:
#        rank country_full  ... confederation   rank_date
# 0         1      Germany  ...          UEFA  1993-08-08
# 1         2        Italy  ...          UEFA  1993-08-08
# 2         3  Switzerland  ...          UEFA  1993-08-08
# 3         4       Sweden  ...          UEFA  1993-08-08
# 4         5    Argentina  ...      CONMEBOL  1993-08-08
# ...     ...          ...  ...           ...         ...
# 57788   206     Anguilla  ...      CONCACAF  2018-06-07
# 57789   206      Bahamas  ...      CONCACAF  2018-06-07
# 57790   206      Eritrea  ...           CAF  2018-06-07
# 57791   206      Somalia  ...           CAF  2018-06-07
# 57792   206        Tonga  ...           OFC  2018-06-07
#
# [57793 rows x 16 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/christianwbsn/world-cup-2018-predictor/master/input/fifa_ranking.csv")
# Out:
#        rank country_full  ... confederation   rank_date
# 0         1      Germany  ...          UEFA  1993-08-08
# 1         2        Italy  ...          UEFA  1993-08-08
# 2         3  Switzerland  ...          UEFA  1993-08-08
# 3         4       Sweden  ...          UEFA  1993-08-08
# 4         5    Argentina  ...      CONMEBOL  1993-08-08
# ...     ...          ...  ...           ...         ...
# 57788   206     Anguilla  ...      CONCACAF  2018-06-07
# 57789   206      Bahamas  ...      CONCACAF  2018-06-07
# 57790   206      Eritrea  ...           CAF  2018-06-07
# 57791   206      Somalia  ...           CAF  2018-06-07
# 57792   206        Tonga  ...           OFC  2018-06-07
#
# [57793 rows x 16 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/christianwbsn/world-cup-2018-predictor/master/input/results.csv")
# Out:
#              date home_team     away_team  ...           city   country neutral
# 0      1872-11-30  Scotland       England  ...        Glasgow  Scotland   False
# 1      1873-03-08   England      Scotland  ...         London   England   False
# 2      1874-03-07  Scotland       England  ...        Glasgow  Scotland   False
# 3      1875-03-06   England      Scotland  ...         London   England   False
# 4      1876-03-04  Scotland       England  ...        Glasgow  Scotland   False
# ...           ...       ...           ...  ...            ...       ...     ...
# 39065  2018-06-19    Poland       Senegal  ...         Moscow    Russia    True
# 39066  2018-06-19    Russia         Egypt  ...  St Petersburg    Russia   False
# 39067  2018-06-20  Portugal       Morocco  ...         Moscow    Russia    True
# 39068  2018-06-20   Uruguay  Saudi Arabia  ...  Rostov-on-Don    Russia    True
# 39069  2018-06-20      Iran         Spain  ...          Kazan    Russia    True
#
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/christianwbsn/world-cup-2018-predictor/master/input/world_cup_2018.csv")
# Out:
#             Team  ... history with\n third opponent\n goals
# 0         Russia  ...                                   0.0
# 1   Saudi Arabia  ...                                  -5.0
# 2          Egypt  ...                                   5.0
# 3        Uruguay  ...                                   0.0
# 4       Portugal  ...                                   5.0
# 5          Spain  ...                                   7.0
# 6        Morocco  ...                                  -7.0
# 7           IRAN  ...                                  -5.0
# 8         France  ...                                   9.0
# 9      Australia  ...                                   NaN
# 10          Peru  ...                                   NaN
# 11       Denmark  ...                                  -9.0
# 12     Argentina  ...                                   1.0
# 13       Iceland  ...                                  -9.0
# 14       Croatia  ...                                   9.0
# ...

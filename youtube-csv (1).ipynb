# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
YouTube = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/pandas/master/dataset/YouTube.csv")

YouTube
# Out:
#                           Category: All categories
# Region                YouTube: (8/15/19 - 8/15/20)
# Mississippi                                    100
# Hawaii                                          97
# Alaska                                          97
# Louisiana                                       95
# Montana                                         94
# New Mexico                                      94
# Vermont                                         93
# New Jersey                                      92
# Maine                                           91
# North Carolina                                  91
# California                                      91
# Arkansas                                        91
# Kentucky                                        91
# South Dakota                                    91
# Wyoming                                         90
# Idaho                                           90
# ...

# %%
YouTube.head()
# Out:
#                  Category: All categories
# Region       YouTube: (8/15/19 - 8/15/20)
# Mississippi                           100
# Hawaii                                 97
# Alaska                                 97
# Louisiana                              95

# %%
YouTube.tail()
# Out:
#                      Category: All categories
# New York                                   83
# Massachusetts                              82
# Nebraska                                   82
# Colorado                                   79
# District of Columbia                       75

# %%
YouTube.describe()
# Out:
#        Category: All categories
# count                        52
# unique                       19
# top                          87
# freq                          8

# %%
YouTube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, Region to District of Columbia
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Category: All categories  52 non-null     object
# dtypes: object(1)
# memory usage: 832.0+ bytes

# %%
YouTube.info
# Out:
# <bound method DataFrame.info of                           Category: All categories
# Region                YouTube: (8/15/19 - 8/15/20)
# Mississippi                                    100
# Hawaii                                          97
# Alaska                                          97
# Louisiana                                       95
# Montana                                         94
# New Mexico                                      94
# Vermont                                         93
# New Jersey                                      92
# Maine                                           91
# North Carolina                                  91
# California                                      91
# Arkansas                                        91
# Kentucky                                        91
# South Dakota                                    91
# Wyoming                                         90
# Idaho                                           90
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("YouTube.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("YouTube.db")
c = conn.cursor()

# %%
YouTube.to_sql("YouTube", conn, if_exists='replace')
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM YouTube""")
rows = c.fetchall()
rows
# Out:
# [('Region', 'YouTube: (8/15/19 - 8/15/20)'),
#  ('Mississippi', '100'),
#  ('Hawaii', '97'),
#  ('Alaska', '97'),
#  ('Louisiana', '95'),
#  ('Montana', '94'),
#  ('New Mexico', '94'),
#  ('Vermont', '93'),
#  ('New Jersey', '92'),
#  ('Maine', '91'),
#  ('North Carolina', '91'),
#  ('California', '91'),
#  ('Arkansas', '91'),
#  ('Kentucky', '91'),
#  ('South Dakota', '91'),
#  ('Wyoming', '90'),
#  ('Idaho', '90'),
#  ('Maryland', '90'),
#  ('Delaware', '89'),
#  ('Rhode Island', '89'),
#  ('North Dakota', '89'),
#  ('Alabama', '89'),
#  ('Connecticut', '88'),
#  ('Georgia', '88'),
#  ('Minnesota', '88'),
#  ('Washington', '88'),
#  ('South Carolina', '87'),
#  ('Iowa', '87'),
#  ('Ohio', '87'),
#  ('Oregon', '87'),
#  ('Wisconsin', '87'),
#  ('Florida', '87'),
#  ('Pennsylvania', '87'),
#  ('Virginia', '87'),
#  ('Utah', '86'),
#  ('West Virginia', '86'),
#  ('New Hampshire', '86'),
#  ('Michigan', '86'),
#  ('Nevada', '85'),
#  ('Texas', '85'),
#  ('Oklahoma', '85'),
# ...

# %%
YouTube.to_excel("YouTube.xls")

pd.read_excel("YouTube.xls")
# Out:
#               Unnamed: 0      Category: All categories
# 0                 Region  YouTube: (8/15/19 - 8/15/20)
# 1            Mississippi                           100
# 2                 Hawaii                            97
# 3                 Alaska                            97
# 4              Louisiana                            95
# 5                Montana                            94
# 6             New Mexico                            94
# 7                Vermont                            93
# 8             New Jersey                            92
# 9                  Maine                            91
# 10        North Carolina                            91
# 11            California                            91
# 12              Arkansas                            91
# 13              Kentucky                            91
# 14          South Dakota                            91
# 15               Wyoming                            90
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('YouTube', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('YouTube')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
YouTube.shape
# Out:
# (52, 1)

# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-panda/blob/master/WeChat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
WeChat = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/WeChat.csv")

WeChat
# Out:
#                          Category: All categories
# Region                WeChat: (8/16/19 - 8/16/20)
# California                                    100
# New York                                       80
# District of Columbia                           77
# Massachusetts                                  74
# Washington                                     61
# New Jersey                                     59
# Hawaii                                         58
# Maryland                                       49
# Delaware                                       43
# Nevada                                         40
# Oregon                                         39
# Illinois                                       37
# Connecticut                                    36
# Virginia                                       35
# Pennsylvania                                   34
# Michigan                                       31
# New Hampshire                                  30
# ...

# %%
WeChat.head()
# Out:
#                          Category: All categories
# Region                WeChat: (8/16/19 - 8/16/20)
# California                                    100
# New York                                       80
# District of Columbia                           77
# Massachusetts                                  74

# %%
WeChat.tail()
# Out:
#               Category: All categories
# Louisiana                           15
# North Dakota                        15
# Nebraska                            14
# Montana                             14
# West Virginia                       13

# %%
WeChat.describe()
# Out:
#        Category: All categories
# count                        52
# unique                       35
# top                          17
# freq                          4

# %%
WeChat.info
# Out:
# <bound method DataFrame.info of                          Category: All categories
# Region                WeChat: (8/16/19 - 8/16/20)
# California                                    100
# New York                                       80
# District of Columbia                           77
# Massachusetts                                  74
# Washington                                     61
# New Jersey                                     59
# Hawaii                                         58
# Maryland                                       49
# Delaware                                       43
# Nevada                                         40
# Oregon                                         39
# Illinois                                       37
# Connecticut                                    36
# Virginia                                       35
# Pennsylvania                                   34
# Michigan                                       31
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("WeChat.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("WeChat.db")
c = conn.cursor()

# %%
WeChat.to_sql("WeChat", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM WeChat""")
rows = c.fetchall()
rows
# Out:
# [('Region', 'WeChat: (8/16/19 - 8/16/20)'),
#  ('California', '100'),
#  ('New York', '80'),
#  ('District of Columbia', '77'),
#  ('Massachusetts', '74'),
#  ('Washington', '61'),
#  ('New Jersey', '59'),
#  ('Hawaii', '58'),
#  ('Maryland', '49'),
#  ('Delaware', '43'),
#  ('Nevada', '40'),
#  ('Oregon', '39'),
#  ('Illinois', '37'),
#  ('Connecticut', '36'),
#  ('Virginia', '35'),
#  ('Pennsylvania', '34'),
#  ('Michigan', '31'),
#  ('New Hampshire', '30'),
#  ('Georgia', '29'),
#  ('Texas', '29'),
#  ('Iowa', '28'),
#  ('Rhode Island', '28'),
#  ('Minnesota', '27'),
#  ('Vermont', '26'),
#  ('North Carolina', '26'),
#  ('Utah', '26'),
#  ('Ohio', '25'),
#  ('Indiana', '25'),
#  ('Wisconsin', '24'),
#  ('South Dakota', '24'),
#  ('Missouri', '23'),
#  ('Arizona', '23'),
#  ('Florida', '22'),
#  ('Colorado', '21'),
#  ('Oklahoma', '21'),
#  ('Kansas', '20'),
#  ('Wyoming', '19'),
#  ('Idaho', '18'),
#  ('Alabama', '17'),
#  ('Alaska', '17'),
#  ('Tennessee', '17'),
# ...

# %%
WeChat.to_excel("WeChat.xls")

pd.read_excel("WeChat.xls")
# Out:
#               Unnamed: 0     Category: All categories
# 0                 Region  WeChat: (8/16/19 - 8/16/20)
# 1             California                          100
# 2               New York                           80
# 3   District of Columbia                           77
# 4          Massachusetts                           74
# 5             Washington                           61
# 6             New Jersey                           59
# 7                 Hawaii                           58
# 8               Maryland                           49
# 9               Delaware                           43
# 10                Nevada                           40
# 11                Oregon                           39
# 12              Illinois                           37
# 13           Connecticut                           36
# 14              Virginia                           35
# 15          Pennsylvania                           34
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('WeChat', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('WeChat')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()

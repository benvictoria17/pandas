# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
Yellow = pd.read_csv("https://raw.githubusercontent.com/bigdata-vandy/spark-taxi/master/yellow_tripdata_2015-01.csv")

Yellow
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1           1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2           1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3           1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4           1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
# ..        ...                  ...                   ...              ...
# 994         1  2015-01-07 20:40:04   2015-01-07 20:42:07                1
# 995         1  2015-01-07 20:40:04   2015-01-07 20:43:01                1
# 996         1  2015-01-07 20:40:04   2015-01-07 21:02:43                2
# 997         1  2015-01-07 20:40:04   2015-01-07 20:47:36                2
# 998         1  2015-01-07 20:40:05   2015-01-07 21:04:15                1
#
#      trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# ...

# %%
Yellow.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
Yellow.tail()
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 994         1  2015-01-07 20:40:04   2015-01-07 20:42:07                1
# 995         1  2015-01-07 20:40:04   2015-01-07 20:43:01                1
# 996         1  2015-01-07 20:40:04   2015-01-07 21:02:43                2
# 997         1  2015-01-07 20:40:04   2015-01-07 20:47:36                2
# 998         1  2015-01-07 20:40:05   2015-01-07 21:04:15                1
#
#      trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 994            0.3          0.000000         0.000000           1
# 995            0.5        -73.993576        40.741859           1
# 996            4.2        -74.001778        40.739468           1
# 997            1.2        -74.002380        40.737835           1
# 998            4.5        -73.986290        40.752693           1
#
#     store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
Yellow.describe()
# Out:
#          VendorID  passenger_count  trip_distance  pickup_longitude  \
# count  999.000000       999.000000     999.000000        999.000000
# mean     1.451451         1.552553       2.780991        -72.642513
# std      0.497887         1.161762       3.126024          9.844933
# min      1.000000         1.000000       0.000000        -74.035690
# 25%      1.000000         1.000000       1.000000        -73.993305
# 50%      1.000000         1.000000       1.700000        -73.982567
# 75%      2.000000         2.000000       3.200000        -73.966335
# max      2.000000         6.000000      28.660000          0.000000
#
#        pickup_latitude  RateCodeID  dropoff_longitude  dropoff_latitude  \
# count       999.000000  999.000000         999.000000        999.000000
# mean         40.015028    1.041041         -72.567412         39.975907
# std           5.423102    0.342859          10.109395          5.569119
# ...

# %%
Yellow.info
# Out:
# <bound method DataFrame.info of      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1           1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2           1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3           1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4           1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
# ..        ...                  ...                   ...              ...
# 994         1  2015-01-07 20:40:04   2015-01-07 20:42:07                1
# 995         1  2015-01-07 20:40:04   2015-01-07 20:43:01                1
# 996         1  2015-01-07 20:40:04   2015-01-07 21:02:43                2
# 997         1  2015-01-07 20:40:04   2015-01-07 20:47:36                2
# 998         1  2015-01-07 20:40:05   2015-01-07 21:04:15                1
#
# ...

# %%
Yellow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               999 non-null    int64
#  1   tpep_pickup_datetime   999 non-null    object
#  2   tpep_dropoff_datetime  999 non-null    object
#  3   passenger_count        999 non-null    int64
#  4   trip_distance          999 non-null    float64
#  5   pickup_longitude       999 non-null    float64
#  6   pickup_latitude        999 non-null    float64
#  7   RateCodeID             999 non-null    int64
#  8   store_and_fwd_flag     999 non-null    object
#  9   dropoff_longitude      999 non-null    float64
#  10  dropoff_latitude       999 non-null    float64
#  11  payment_type           999 non-null    int64
#  12  fare_amount            999 non-null    float64
#  13  extra                  999 non-null    float64
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("Yellow.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("Yellow.db")
c = conn.cursor()

# %%
Yellow.to_sql("Yellow", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM Yellow""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   2,
#   '2015-01-15 19:05:39',
#   '2015-01-15 19:23:42',
#   1,
#   1.59,
#   -73.993896484375,
#   40.7501106262207,
#   1,
#   'N',
#   -73.97478485107422,
#   40.75061798095703,
#   1,
#   12.0,
#   1.0,
#   0.5,
#   3.25,
#   0.0,
#   0.3,
#   17.05),
#  (1,
#   1,
#   '2015-01-10 20:33:38',
#   '2015-01-10 20:53:28',
#   1,
#   3.3,
#   -74.00164794921875,
#   40.7242431640625,
#   1,
#   'N',
#   -73.99441528320312,
#   40.75910949707031,
#   1,
#   14.5,
#   0.5,
#   0.5,
#   2.0,
#   0.0,
#   0.3,
#   17.8),
#  (2,
#   1,
#   '2015-01-10 20:33:38',
#   '2015-01-10 20:43:41',
#   1,
#   1.8,
#   -73.96334075927734,
#   40.80278778076172,
#   1,
#   'N',
#   -73.95182037353516,
#   40.82441329956055,
#   2,
#   9.5,
#   0.5,
#   0.5,
#   0.0,
#   0.0,
#   0.3,
#   10.8),
#  (3,
#   1,
#   '2015-01-10 20:33:39',
#   '2015-01-10 20:35:31',
#   1,
#   0.5,
#   -74.00908660888672,
#   40.71381759643555,
#   1,
#   'N',
#   -74.00432586669923,
#   40.71998596191406,
#   2,
# ...

# %%
Yellow.to_excel("Yellow.xls")

pd.read_excel("Yellow.xls")
# Out:
#      Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0             0         2  2015-01-15 19:05:39   2015-01-15 19:23:42
# 1             1         1  2015-01-10 20:33:38   2015-01-10 20:53:28
# 2             2         1  2015-01-10 20:33:38   2015-01-10 20:43:41
# 3             3         1  2015-01-10 20:33:39   2015-01-10 20:35:31
# 4             4         1  2015-01-10 20:33:39   2015-01-10 20:52:58
# ..          ...       ...                  ...                   ...
# 994         994         1  2015-01-07 20:40:04   2015-01-07 20:42:07
# 995         995         1  2015-01-07 20:40:04   2015-01-07 20:43:01
# 996         996         1  2015-01-07 20:40:04   2015-01-07 21:02:43
# 997         997         1  2015-01-07 20:40:04   2015-01-07 20:47:36
# 998         998         1  2015-01-07 20:40:05   2015-01-07 21:04:15
#
#      passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Yellow-Taxi-Demand-Prediction', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Yellow-Taxi-Demand-Prediction')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %%
Webdevelopment = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/Web%20development.csv")

Webdevelopment
# Out:
#                                   Category: All categories
# Region                Web development: (8/14/19 - 8/14/20)
# District of Columbia                                   100
# New York                                                85
# Connecticut                                             59
# Kansas                                                  57
# Georgia                                                 56
# New Jersey                                              56
# California                                              56
# Virginia                                                55
# Mississippi                                             54
# Utah                                                    54
# North Carolina                                          53
# Maryland                                                53
# Florida                                                 51
# South Carolina                                          50
# ...

# %%
Webdevelopment.head()
# Out:
#                                   Category: All categories
# Region                Web development: (8/14/19 - 8/14/20)
# District of Columbia                                   100
# New York                                                85
# Connecticut                                             59
# Kansas                                                  57

# %%
Webdevelopment.tail()
# Out:
#               Category: All categories
# West Virginia                       28
# Montana                             27
# Wyoming                             25
# South Dakota                        25
# Hawaii                              24

# %%
Webdevelopment.describe()
# Out:
#        Category: All categories
# count                        52
# unique                       34
# top                          46
# freq                          4

# %%
import sqlite3

# %%
conn = sqlite3.connect("Webdevelopment.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("Webdevelopment.db")
c = conn.cursor()

# %%
Webdevelopment.to_sql("Webdevelopment", conn, if_exists='replace')
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:2612: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM Webdevelopment""")
rows = c.fetchall()
rows
# Out:
# [('Region', 'Web development: (8/14/19 - 8/14/20)'),
#  ('District of Columbia', '100'),
#  ('New York', '85'),
#  ('Connecticut', '59'),
#  ('Kansas', '57'),
#  ('Georgia', '56'),
#  ('New Jersey', '56'),
#  ('California', '56'),
#  ('Virginia', '55'),
#  ('Mississippi', '54'),
#  ('Utah', '54'),
#  ('North Carolina', '53'),
#  ('Maryland', '53'),
#  ('Florida', '51'),
#  ('South Carolina', '50'),
#  ('Kentucky', '50'),
#  ('Arizona', '50'),
#  ('Illinois', '49'),
#  ('Oregon', '48'),
#  ('Colorado', '48'),
#  ('Massachusetts', '47'),
#  ('Washington', '47'),
#  ('Nevada', '46'),
#  ('Louisiana', '46'),
#  ('Texas', '46'),
#  ('Rhode Island', '46'),
#  ('Pennsylvania', '45'),
#  ('Tennessee', '44'),
#  ('Alabama', '44'),
#  ('Minnesota', '43'),
#  ('Ohio', '42'),
#  ('Michigan', '41'),
#  ('Iowa', '41'),
#  ('Arkansas', '41'),
#  ('Delaware', '40'),
#  ('Indiana', '39'),
#  ('New Mexico', '38'),
#  ('Wisconsin', '38'),
#  ('Missouri', '37'),
#  ('Idaho', '37'),
# ...

# %%
Webdevelopment.to_excel("Webdevelopment.xls")

pd.read_excel("Webdevelopment.xls")
# Out:
#               Unnamed: 0              Category: All categories
# 0                 Region  Web development: (8/14/19 - 8/14/20)
# 1   District of Columbia                                   100
# 2               New York                                    85
# 3            Connecticut                                    59
# 4                 Kansas                                    57
# 5                Georgia                                    56
# 6             New Jersey                                    56
# 7             California                                    56
# 8               Virginia                                    55
# 9            Mississippi                                    54
# 10                  Utah                                    54
# 11        North Carolina                                    53
# 12              Maryland                                    53
# 13               Florida                                    51
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Web development', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Web development')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()

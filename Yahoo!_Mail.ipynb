# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-panda/blob/master/Yahoo!_Mail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %%
YahooMail = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/yahoo%20mail.csv")

YahooMail
# Out:
#                 Category: All categories
# Week        Yahoo! Mail: (United States)
# 2019-08-18                            84
# 2019-08-25                            82
# 2019-09-01                            75
# 2019-09-08                            78
# 2019-09-15                            76
# 2019-09-22                            80
# 2019-09-29                            81
# 2019-10-06                            79
# 2019-10-13                            79
# 2019-10-20                            80
# 2019-10-27                            80
# 2019-11-03                            82
# 2019-11-10                            81
# 2019-11-17                            81
# 2019-11-24                            76
# 2019-12-01                            88
# 2019-12-08                            84
# 2019-12-15                            85
# 2019-12-22                            76
# 2019-12-29                            78
# 2020-01-05                            83
# ...

# %%
YahooMail.head()
# Out:
#                 Category: All categories
# Week        Yahoo! Mail: (United States)
# 2019-08-18                            84
# 2019-08-25                            82
# 2019-09-01                            75
# 2019-09-08                            78

# %%
YahooMail.tail()
# Out:
#            Category: All categories
# 2020-07-12                       90
# 2020-07-19                       82
# 2020-07-26                       85
# 2020-08-02                       83
# 2020-08-09                       83

# %%
YahooMail.describe()
# Out:
#        Category: All categories
# count                        53
# unique                       21
# top                          84
# freq                          6

# %%
YahooMail.describe()
# Out:
#        Category: All categories
# count                        53
# unique                       21
# top                          84
# freq                          6

# %%
import sqlite3

# %%
conn = sqlite3.connect("YahooMail.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("YahooMail.db")
c = conn.cursor()

# %%
YahooMail.to_sql("YahooMail", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM YahooMail""")
rows = c.fetchall()
rows
# Out:
# [('Week', 'Yahoo! Mail: (United States)'),
#  ('2019-08-18', '84'),
#  ('2019-08-25', '82'),
#  ('2019-09-01', '75'),
#  ('2019-09-08', '78'),
#  ('2019-09-15', '76'),
#  ('2019-09-22', '80'),
#  ('2019-09-29', '81'),
#  ('2019-10-06', '79'),
#  ('2019-10-13', '79'),
#  ('2019-10-20', '80'),
#  ('2019-10-27', '80'),
#  ('2019-11-03', '82'),
#  ('2019-11-10', '81'),
#  ('2019-11-17', '81'),
#  ('2019-11-24', '76'),
#  ('2019-12-01', '88'),
#  ('2019-12-08', '84'),
#  ('2019-12-15', '85'),
#  ('2019-12-22', '76'),
#  ('2019-12-29', '78'),
#  ('2020-01-05', '83'),
#  ('2020-01-12', '81'),
#  ('2020-01-19', '82'),
#  ('2020-01-26', '84'),
#  ('2020-02-02', '84'),
#  ('2020-02-09', '86'),
#  ('2020-02-16', '84'),
#  ('2020-02-23', '85'),
#  ('2020-03-01', '84'),
#  ('2020-03-08', '85'),
#  ('2020-03-15', '88'),
#  ('2020-03-22', '93'),
#  ('2020-03-29', '91'),
#  ('2020-04-05', '96'),
#  ('2020-04-12', '100'),
#  ('2020-04-19', '97'),
#  ('2020-04-26', '98'),
#  ('2020-05-03', '96'),
# ...

# %%
YahooMail.to_excel("YahooMail.xls")

pd.read_excel("YahooMail.xls")
# Out:
#     Unnamed: 0      Category: All categories
# 0         Week  Yahoo! Mail: (United States)
# 1   2019-08-18                            84
# 2   2019-08-25                            82
# 3   2019-09-01                            75
# 4   2019-09-08                            78
# 5   2019-09-15                            76
# 6   2019-09-22                            80
# 7   2019-09-29                            81
# 8   2019-10-06                            79
# 9   2019-10-13                            79
# 10  2019-10-20                            80
# 11  2019-10-27                            80
# 12  2019-11-03                            82
# 13  2019-11-10                            81
# 14  2019-11-17                            81
# 15  2019-11-24                            76
# 16  2019-12-01                            88
# 17  2019-12-08                            84
# 18  2019-12-15                            85
# 19  2019-12-22                            76
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Yahoo! Mail', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Yahoo! Mail')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()

# %%
YahooMail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53 entries, Week to 2020-08-09
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Category: All categories  53 non-null     object
# dtypes: object(1)
# memory usage: 848.0+ bytes

# %%
YahooMail.info
# Out:
# <bound method DataFrame.info of                 Category: All categories
# Week        Yahoo! Mail: (United States)
# 2019-08-18                            84
# 2019-08-25                            82
# 2019-09-01                            75
# 2019-09-08                            78
# 2019-09-15                            76
# 2019-09-22                            80
# 2019-09-29                            81
# 2019-10-06                            79
# 2019-10-13                            79
# 2019-10-20                            80
# 2019-10-27                            80
# 2019-11-03                            82
# 2019-11-10                            81
# 2019-11-17                            81
# 2019-11-24                            76
# 2019-12-01                            88
# 2019-12-08                            84
# 2019-12-15                            85
# 2019-12-22                            76
# 2019-12-29                            78
# ...

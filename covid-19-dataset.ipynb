# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import sqlite3

# %%
state = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv")


state
# Out:
#              date          state  fips   cases  deaths
# 0      2020-01-21     Washington    53       1       0
# 1      2020-01-22     Washington    53       1       0
# 2      2020-01-23     Washington    53       1       0
# 3      2020-01-24       Illinois    17       1       0
# 4      2020-01-24     Washington    53       1       0
# ...           ...            ...   ...     ...     ...
# 10404  2020-09-07       Virginia    51  127571    2684
# 10405  2020-09-07     Washington    53   80486    2044
# 10406  2020-09-07  West Virginia    54   11575     247
# 10407  2020-09-07      Wisconsin    55   86981    1177
# 10408  2020-09-07        Wyoming    56    4032      42
#
# [10409 rows x 5 columns]

# %%
state.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
state.tail()
# Out:
#              date          state  fips   cases  deaths
# 10404  2020-09-07       Virginia    51  127571    2684
# 10405  2020-09-07     Washington    53   80486    2044
# 10406  2020-09-07  West Virginia    54   11575     247
# 10407  2020-09-07      Wisconsin    55   86981    1177
# 10408  2020-09-07        Wyoming    56    4032      42

# %%
state.describe()
# Out:
#                fips          cases        deaths
# count  10409.000000   10409.000000  10409.000000
# mean      31.823326   43547.833606   1737.299452
# std       18.593383   89073.450516   4178.949684
# min        1.000000       1.000000      0.000000
# 25%       17.000000    1217.000000     23.000000
# 50%       31.000000   10292.000000    312.000000
# 75%       46.000000   46717.000000   1512.000000
# max       78.000000  742689.000000  32600.000000

# %%
state.info
# Out:
# <bound method DataFrame.info of              date          state  fips   cases  deaths
# 0      2020-01-21     Washington    53       1       0
# 1      2020-01-22     Washington    53       1       0
# 2      2020-01-23     Washington    53       1       0
# 3      2020-01-24       Illinois    17       1       0
# 4      2020-01-24     Washington    53       1       0
# ...           ...            ...   ...     ...     ...
# 10404  2020-09-07       Virginia    51  127571    2684
# 10405  2020-09-07     Washington    53   80486    2044
# 10406  2020-09-07  West Virginia    54   11575     247
# 10407  2020-09-07      Wisconsin    55   86981    1177
# 10408  2020-09-07        Wyoming    56    4032      42
#
# [10409 rows x 5 columns]>

# %%
state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10409 entries, 0 to 10408
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    10409 non-null  object
#  1   state   10409 non-null  object
#  2   fips    10409 non-null  int64
#  3   cases   10409 non-null  int64
#  4   deaths  10409 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 406.7+ KB

# %%
import sqlite3

# %%
conn = sqlite3.connect("state.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("state.db")
c = conn.cursor()

# %%
state.to_sql("state", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM state""")
rows = c.fetchall()
rows[0:999]
# Out:
# [(0, '2020-01-21', 'Washington', 53, 1, 0),
#  (1, '2020-01-22', 'Washington', 53, 1, 0),
#  (2, '2020-01-23', 'Washington', 53, 1, 0),
#  (3, '2020-01-24', 'Illinois', 17, 1, 0),
#  (4, '2020-01-24', 'Washington', 53, 1, 0),
#  (5, '2020-01-25', 'California', 6, 1, 0),
#  (6, '2020-01-25', 'Illinois', 17, 1, 0),
#  (7, '2020-01-25', 'Washington', 53, 1, 0),
#  (8, '2020-01-26', 'Arizona', 4, 1, 0),
#  (9, '2020-01-26', 'California', 6, 2, 0),
#  (10, '2020-01-26', 'Illinois', 17, 1, 0),
#  (11, '2020-01-26', 'Washington', 53, 1, 0),
#  (12, '2020-01-27', 'Arizona', 4, 1, 0),
#  (13, '2020-01-27', 'California', 6, 2, 0),
#  (14, '2020-01-27', 'Illinois', 17, 1, 0),
#  (15, '2020-01-27', 'Washington', 53, 1, 0),
#  (16, '2020-01-28', 'Arizona', 4, 1, 0),
#  (17, '2020-01-28', 'California', 6, 2, 0),
#  (18, '2020-01-28', 'Illinois', 17, 1, 0),
#  (19, '2020-01-28', 'Washington', 53, 1, 0),
#  (20, '2020-01-29', 'Arizona', 4, 1, 0),
#  (21, '2020-01-29', 'California', 6, 2, 0),
# ...

# %%
state.to_excel("state.xls")

pd.read_excel("state.xls")
# Out:
#        Unnamed: 0        date          state  fips   cases  deaths
# 0               0  2020-01-21     Washington    53       1       0
# 1               1  2020-01-22     Washington    53       1       0
# 2               2  2020-01-23     Washington    53       1       0
# 3               3  2020-01-24       Illinois    17       1       0
# 4               4  2020-01-24     Washington    53       1       0
# ...           ...         ...            ...   ...     ...     ...
# 10404       10404  2020-09-07       Virginia    51  127571    2684
# 10405       10405  2020-09-07     Washington    53   80486    2044
# 10406       10406  2020-09-07  West Virginia    54   11575     247
# 10407       10407  2020-09-07      Wisconsin    55   86981    1177
# 10408       10408  2020-09-07        Wyoming    56    4032      42
#
# [10409 rows x 6 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('covid-19 state dataset', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('covid-19 state dataset')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
